# %%
import matplotlib.pyplot as plt

# %%
#以lr0.00001为例
lr=0.00001
#读取数据就是从data.txt复制粘贴需要的数据，数据用逗号隔开，所以可以直接作为列表输入
#从而可以直接作为绘图的基础
train_acc_2=[0.5363,0.6159,0.6984,0.7647,0.8137,0.8394,0.8772]
train_acc_1=[0.5363,0.6156,0.6787,0.7431,0.7963,0.8219,0.8650]
train_acc_0=[0.4709,0.5819,0.5863,0.6238,0.6503,0.6856,0.7262]
test_acc_2=[0.6075,0.6725,0.6925,0.6850,0.6887,0.6883,0.6800]
test_acc_1=[0.5962,0.6438,0.6550,0.6650,0.6550,0.6700,0.6538]
test_acc_0=[0.6000,0.6062,0.6088,0.6325,0.6450,0.6525,0.6500]

# %%
epoch = [1,2,3,4,5,6,7]
plt.plot(epoch,train_acc_2,'s-',color = 'r',label="train_mix")
plt.plot(epoch,test_acc_2,'s-',color = 'r',label="test_mix")
plt.plot(epoch,train_acc_1,'o-',color = 'b',label="train_text")
plt.plot(epoch,test_acc_1,'o-',color = 'b',label="test_text")
plt.plot(epoch,train_acc_0,'*-',color = 'g',label="train_img")
plt.plot(epoch,test_acc_0,'*-',color = 'g',label="test_img")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend(loc = "best")
plt.title('Multimodal-sentiment-analysis when lr=1e-05')
plt.savefig('./img/sample.png')
plt.show()
